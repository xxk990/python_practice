# %%
import requests
url = 'https://api.github.com/search/repositories?q=language:python&sort=stars'
r= requests.get(url)
print("Status code:", r.status_code)
response_dict = r.json()

print("Total repositories:",response_dict['total_count'])

repo_dicts = response_dict['items']
print("Repositories returned:", len(repo_dicts))

repo_dict = repo_dicts[0]
print("\nKeys:", len(repo_dict))
for key in sorted(repo_dict.keys()):
    print(key)
# Out:
# Status code: 200
# Total repositories: 3914881
# Repositories returned: 30
#
# Keys: 74
# archive_url
# archived
# assignees_url
# blobs_url
# branches_url
# clone_url
# collaborators_url
# comments_url
# commits_url
# compare_url
# contents_url
# contributors_url
# created_at
# default_branch
# deployments_url
# description
# disabled
# downloads_url
# events_url
# fork
# forks
# forks_count
# forks_url
# full_name
# git_commits_url
# git_refs_url
# git_tags_url
# git_url
# has_downloads
# has_issues
# has_pages
# has_projects
# has_wiki
# homepage
# hooks_url
# html_url
# id
# issue_comment_url
# issue_events_url
# issues_url
# keys_url
# labels_url
# language
# languages_url
# license
# merges_url
# milestones_url
# mirror_url
# name
# node_id
# notifications_url
# open_issues
# open_issues_count
# owner
# private
# pulls_url
# pushed_at
# releases_url
# score
# size
# ssh_url
# stargazers_count
# stargazers_url
# statuses_url
# subscribers_url
# subscription_url
# svn_url
# tags_url
# teams_url
# trees_url
# updated_at
# url
# watchers
# watchers_count

# %%
import requests
url = 'https://api.github.com/search/repositories?q=language:python&sort=stars'
r= requests.get(url)
print("Status code:", r.status_code)
response_dict = r.json()

print("Total repositories:",response_dict['total_count'])

repo_dicts = response_dict['items']
print("Repositories returned:", len(repo_dicts))

repo_dict = repo_dicts[0]

print("\nSelected information about first repository:")
print('Name:', repo_dict['name'])
print('Owner:', repo_dict['owner']['login'])
print('Stars:', repo_dict['stargazers_count'])
print('Repository:', repo_dict['html_url'])
print('Created:', repo_dict['created_at'])
print('Updated:', repo_dict['updated_at'])
print('Description:', repo_dict['description'])
# Out:
# Status code: 200
# Total repositories: 3914899
# Repositories returned: 30
#
# Selected information about first repository:
# Name: awesome-python
# Owner: vinta
# Stars: 68792
# Repository: https://github.com/vinta/awesome-python
# Created: 2014-06-27T21:00:06Z
# Updated: 2019-06-17T16:26:15Z
# Description: A curated list of awesome Python frameworks, libraries, software and resources

# %%
import requests
url = 'https://api.github.com/search/repositories?q=language:python&sort=stars'
r= requests.get(url)
print("Status code:", r.status_code)
response_dict = r.json()

print("Total repositories:",response_dict['total_count'])

repo_dicts = response_dict['items']
print("Repositories returned:", len(repo_dicts))

for repo_dict in repo_dicts:
    print("\nSelected information about first repository:")
    print('Name:', repo_dict['name'])
    print('Owner:', repo_dict['owner']['login'])
    print('Stars:', repo_dict['stargazers_count'])
    print('Repository:', repo_dict['html_url'])
    print('Created:', repo_dict['created_at'])
    print('Updated:', repo_dict['updated_at'])
    print('Description:', repo_dict['description'])
# Out:
# Status code: 200
# Total repositories: 3914905
# Repositories returned: 30
#
# Selected information about first repository:
# Name: awesome-python
# Owner: vinta
# Stars: 68792
# Repository: https://github.com/vinta/awesome-python
# Created: 2014-06-27T21:00:06Z
# Updated: 2019-06-17T16:26:15Z
# Description: A curated list of awesome Python frameworks, libraries, software and resources
#
# Selected information about first repository:
# Name: system-design-primer
# Owner: donnemartin
# Stars: 64965
# Repository: https://github.com/donnemartin/system-design-primer
# Created: 2017-02-26T16:15:28Z
# Updated: 2019-06-17T17:38:37Z
# Description: Learn how to design large-scale systems. Prep for the system design interview.  Includes Anki flashcards.
#
# Selected information about first repository:
# Name: public-apis
# Owner: public-apis
# Stars: 58201
# Repository: https://github.com/public-apis/public-apis
# Created: 2016-03-20T23:49:42Z
# Updated: 2019-06-17T17:36:50Z
# Description: A collective list of free APIs for use in software and web development.
#
# Selected information about first repository:
# Name: models
# Owner: tensorflow
# Stars: 54163
# Repository: https://github.com/tensorflow/models
# Created: 2016-02-05T01:15:20Z
# Updated: 2019-06-17T17:07:20Z
# Description: Models and examples built with TensorFlow
#
# Selected information about first repository:
# Name: youtube-dl
# Owner: ytdl-org
# Stars: 51577
# Repository: https://github.com/ytdl-org/youtube-dl
# Created: 2010-10-31T14:35:07Z
# Updated: 2019-06-17T17:36:33Z
# Description: Command-line program to download videos from YouTube.com and other video sites
#
# Selected information about first repository:
# Name: Python
# Owner: TheAlgorithms
# Stars: 46220
# Repository: https://github.com/TheAlgorithms/Python
# Created: 2016-07-16T09:44:01Z
# Updated: 2019-06-17T17:39:01Z
# Description: All Algorithms implemented in Python
#
# Selected information about first repository:
# Name: flask
# Owner: pallets
# Stars: 44791
# Repository: https://github.com/pallets/flask
# Created: 2010-04-06T11:11:59Z
# Updated: 2019-06-17T17:20:30Z
# Description: The Python micro framework for building web applications.
#
# Selected information about first repository:
# Name: thefuck
# Owner: nvbn
# Stars: 44258
# Repository: https://github.com/nvbn/thefuck
# Created: 2015-04-08T15:08:04Z
# Updated: 2019-06-17T14:23:01Z
# Description: Magnificent app which corrects your previous console command.
#
# Selected information about first repository:
# Name: django
# Owner: django
# Stars: 42224
# Repository: https://github.com/django/django
# Created: 2012-04-28T02:47:18Z
# Updated: 2019-06-17T17:27:39Z
# Description: The Web framework for perfectionists with deadlines.
#
# Selected information about first repository:
# Name: keras
# Owner: keras-team
# Stars: 42003
# Repository: https://github.com/keras-team/keras
# Created: 2015-03-28T00:35:42Z
# Updated: 2019-06-17T17:38:32Z
# Description: Deep Learning for humans
#
# Selected information about first repository:
# Name: httpie
# Owner: jakubroztocil
# Stars: 41918
# Repository: https://github.com/jakubroztocil/httpie
# Created: 2012-02-25T12:39:13Z
# Updated: 2019-06-17T17:25:40Z
# Description: As easy as httpie /aitch-tee-tee-pie/ 🥧 Modern command line HTTP client – user-friendly curl alternative with intuitive UI, JSON support, syntax highlighting, wget-like downloads, extensions, etc.  https://twitter.com/clihttp
#
# Selected information about first repository:
# Name: awesome-machine-learning
# Owner: josephmisiti
# Stars: 40368
# Repository: https://github.com/josephmisiti/awesome-machine-learning
# Created: 2014-07-15T19:11:19Z
# Updated: 2019-06-17T16:58:00Z
# Description: A curated list of awesome Machine Learning frameworks, libraries and software.
#
# Selected information about first repository:
# Name: requests
# Owner: kennethreitz
# Stars: 38996
# Repository: https://github.com/kennethreitz/requests
# Created: 2011-02-13T18:38:17Z
# Updated: 2019-06-17T17:21:11Z
# Description: Python HTTP Requests for Humans™ ✨🍰✨
#
# Selected information about first repository:
# Name: ansible
# Owner: ansible
# Stars: 37751
# Repository: https://github.com/ansible/ansible
# Created: 2012-03-06T14:58:02Z
# Updated: 2019-06-17T17:27:50Z
# Description: Ansible is a radically simple IT automation platform that makes your applications and systems easier to deploy. Avoid writing scripts or custom code to deploy and update your applications — automate in a language that approaches plain English, using SSH, with no agents to install on remote systems. https://docs.ansible.com/ansible/
#
# Selected information about first repository:
# Name: scikit-learn
# Owner: scikit-learn
# Stars: 35651
# Repository: https://github.com/scikit-learn/scikit-learn
# Created: 2010-08-17T09:43:38Z
# Updated: 2019-06-17T17:23:59Z
# Description: scikit-learn: machine learning in Python
#
# Selected information about first repository:
# Name: scrapy
# Owner: scrapy
# Stars: 33225
# Repository: https://github.com/scrapy/scrapy
# Created: 2010-02-22T02:01:14Z
# Updated: 2019-06-17T17:40:07Z
# Description: Scrapy, a fast high-level web crawling & scraping framework for Python.
#
# Selected information about first repository:
# Name: big-list-of-naughty-strings
# Owner: minimaxir
# Stars: 32522
# Repository: https://github.com/minimaxir/big-list-of-naughty-strings
# Created: 2015-08-08T20:57:20Z
# Updated: 2019-06-17T09:43:47Z
# Description: The Big List of Naughty Strings is a list of strings which have a high probability of causing issues when used as user-input data.
#
# Selected information about first repository:
# Name: shadowsocks
# Owner: shadowsocks
# Stars: 30510
# Repository: https://github.com/shadowsocks/shadowsocks
# Created: 2012-04-20T13:10:49Z
# Updated: 2019-06-17T16:12:49Z
# Description: None
#
# Selected information about first repository:
# Name: XX-Net
# Owner: XX-net
# Stars: 27994
# Repository: https://github.com/XX-net/XX-Net
# Created: 2015-01-15T09:35:51Z
# Updated: 2019-06-17T16:21:12Z
# Description: a web proxy tool
#
# Selected information about first repository:
# Name: certbot
# Owner: certbot
# Stars: 25226
# Repository: https://github.com/certbot/certbot
# Created: 2014-11-12T02:52:20Z
# Updated: 2019-06-17T16:19:30Z
# Description: Certbot is EFF's tool to obtain certs from Let's Encrypt and (optionally) auto-enable HTTPS on your server.  It can also act as a client for any other CA that uses the ACME protocol.
#
# Selected information about first repository:
# Name: you-get
# Owner: soimort
# Stars: 24977
# Repository: https://github.com/soimort/you-get
# Created: 2012-08-20T15:53:36Z
# Updated: 2019-06-17T16:21:14Z
# Description: :arrow_double_down: Dumb downloader that scrapes the web
#
# Selected information about first repository:
# Name: cpython
# Owner: python
# Stars: 24914
# Repository: https://github.com/python/cpython
# Created: 2017-02-10T19:23:51Z
# Updated: 2019-06-17T16:50:51Z
# Description: The Python programming language
#
# Selected information about first repository:
# Name: face_recognition
# Owner: ageitgey
# Stars: 24835
# Repository: https://github.com/ageitgey/face_recognition
# Created: 2017-03-03T21:52:39Z
# Updated: 2019-06-17T16:29:55Z
# Description: The world's simplest facial recognition api for Python and the command line
#
# Selected information about first repository:
# Name: home-assistant
# Owner: home-assistant
# Stars: 24287
# Repository: https://github.com/home-assistant/home-assistant
# Created: 2013-09-17T07:29:48Z
# Updated: 2019-06-17T16:56:06Z
# Description: :house_with_garden: Open source home automation that puts local control and privacy first
#
# Selected information about first repository:
# Name: Algorithm_Interview_Notes-Chinese
# Owner: imhuay
# Stars: 23923
# Repository: https://github.com/imhuay/Algorithm_Interview_Notes-Chinese
# Created: 2018-06-06T12:53:14Z
# Updated: 2019-06-17T16:22:30Z
# Description: 2018/2019/校招/春招/秋招/算法/机器学习(Machine Learning)/深度学习(Deep Learning)/自然语言处理(NLP)/C/C++/Python/面试笔记
#
# Selected information about first repository:
# Name: 100-Days-Of-ML-Code
# Owner: Avik-Jain
# Stars: 23627
# Repository: https://github.com/Avik-Jain/100-Days-Of-ML-Code
# Created: 2018-07-05T09:11:43Z
# Updated: 2019-06-17T17:41:47Z
# Description: 100 Days of ML Coding
#
# Selected information about first repository:
# Name: Deep-Learning-Papers-Reading-Roadmap
# Owner: floodsung
# Stars: 23160
# Repository: https://github.com/floodsung/Deep-Learning-Papers-Reading-Roadmap
# Created: 2016-10-14T11:49:48Z
# Updated: 2019-06-17T15:20:36Z
# Description: Deep Learning papers reading roadmap for anyone who are eager to learn this amazing tech!
#
# Selected information about first repository:
# Name: CppCoreGuidelines
# Owner: isocpp
# Stars: 23140
# Repository: https://github.com/isocpp/CppCoreGuidelines
# Created: 2015-08-19T20:22:52Z
# Updated: 2019-06-17T16:44:27Z
# Description: The C++ Core Guidelines are a set of tried-and-true guidelines, rules, and best practices about coding in C++
#
# Selected information about first repository:
# Name: tldr
# Owner: tldr-pages
# Stars: 22686
# Repository: https://github.com/tldr-pages/tldr
# Created: 2013-12-08T07:34:43Z
# Updated: 2019-06-17T16:40:07Z
# Description: :books: Simplified and community-driven man pages
#
# Selected information about first repository:
# Name: sentry
# Owner: getsentry
# Stars: 21174
# Repository: https://github.com/getsentry/sentry
# Created: 2010-08-30T22:06:41Z
# Updated: 2019-06-17T15:51:35Z
# Description: Sentry is cross-platform application monitoring, with a focus on error reporting.

# %%
import requests
import pygal
from pygal.style import LightColorizedStyle as LCS, LightenStyle as LS
url = 'https://api.github.com/search/repositories?q=language:python&sort=stars'
r= requests.get(url)
print("Status code:", r.status_code)
response_dict = r.json()

print("Total repositories:",response_dict['total_count'])

repo_dicts = response_dict['items']
names, stars = [], []

for repo_dict in repo_dicts:
    names.append(repo_dict['name'])
    stars.append(repo_dict['stargazers_count'])

my_style = LS('#333366', base_style = LCS)
chart = pygal.Bar(style = my_style, x_label_rotation=45, show_legend = False)
chart.title = 'Most-Starred Python Projects on Github'
chart.x_labels = names

chart.add('', stars)
chart.render_to_file('python_repos.svg')
# Out:
# Status code: 200
# Total repositories: 3915580

# %%
import requests
import pygal
from pygal.style import LightColorizedStyle as LCS, LightenStyle as LS
url = 'https://api.github.com/search/repositories?q=language:python&sort=stars'
r= requests.get(url)
print("Status code:", r.status_code)
response_dict = r.json()

print("Total repositories:",response_dict['total_count'])

repo_dicts = response_dict['items']
names, stars = [], []

for repo_dict in repo_dicts:
    names.append(repo_dict['name'])
    stars.append(repo_dict['stargazers_count'])

my_style = LS('#333366', base_style = LCS)
my_config = pygal.Config()
my_config.x_label_rotation = 45
my_config.show_legend = False
my_config.title_font_size = 24
my_config.label_font_size = 14
my_config.major_label_font_size = 18
my_config.truncate_label = 15
my_config.show_y_guides = False
my_config.width = 1000

chart = pygal.Bar(my_config, style = my_style)
chart.title = 'Most-Starred Python Projects on Github'
chart.x_labels = names

chart.add('', stars)
chart.render_to_file('python_repos.svg')
# Out:
# Status code: 200
# Total repositories: 3915589

# %%
my_style = LS('#333366', base_style=LCS)
chart = pygal.Bar(style = my_style, x_label_roration = 45, show_legend = False)
chart.title = 'Python Projects'
chart.x_label = ['httpie', 'django', 'flask']

plot_dicts = [
    {'value': 16101, 'label': 'Description of httpie.'},
    {'value': 15028, 'label': 'Description of django.'},
    {'value': 14798, 'label': 'Description of flask.'},
]

chart.add('', plot_dicts)
chart.render_to_file('bar_descriptions.svg')

# %%
import requests
from operator import itemgetter

url = 'https://hacker-news.firebaseio.com/v0/topstories.json'
r = requests.get(url)
print("Status code:", r.status_code)

submission_ids = r.json()
submission_dicts = []
for submission_id in submission_ids[:30]:
    url = (('https://hacker-news.firebaseio.com/v0/item/' +
                str(submission_id) + '.json'))
    submission_r = requests.get(url)
    print(submission_r.status_code)
    response_dict = submission_r.json()
    
    submission_dict = {
        'title': response_dict['title'],
        'link': 'http://news.ycombinator.com/item?id=' + str(submission_id),
        'comments': response_dict.get('descendants',0)
    }
    submission_dicts.append(submission_dict)
submission_dicts = sorted(submission_dicts, key = itemgetter('comments'), reverse = True)

for submission_dict in submission_dicts:
    print("\nTitle:", submission_dict['title'])
    print("Discussion Line:", submission_dict['link'])
    print("Comments:", submission_dict['comments'])
# Out:
# Status code: 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
#
# Title: Mazda is purging touchscreens from its vehicles
# Discussion Line: http://news.ycombinator.com/item?id=20200335
# Comments: 783
#
# Title: Samsung TVs should be regularly virus-checked, the company says
# Discussion Line: http://news.ycombinator.com/item?id=20205131
# Comments: 360
#
# Title: Facebook’s Libra cryptocurrency: Privacy and stability concerns
# Discussion Line: http://news.ycombinator.com/item?id=20203850
# Comments: 194
#
# Title: The student loan crisis is really an underemployment catastrophe
# Discussion Line: http://news.ycombinator.com/item?id=20203530
# Comments: 179
#
# Title: The Future of Docker Desktop for Windows
# Discussion Line: http://news.ycombinator.com/item?id=20202869
# Comments: 110
#
# Title: Asian countries take a stand against the rich world’s plastic waste
# Discussion Line: http://news.ycombinator.com/item?id=20203497
# Comments: 108
#
# Title: Minnesota court decision means doctors can be sued by patients they don't treat
# Discussion Line: http://news.ycombinator.com/item?id=20204643
# Comments: 90
#
# Title: New Hampshire installs historical marker to honor the creation of BASIC
# Discussion Line: http://news.ycombinator.com/item?id=20202213
# Comments: 67
#
# Title: How much are professors paid?
# Discussion Line: http://news.ycombinator.com/item?id=20205594
# Comments: 59
#
# Title: SACK Panic – Multiple TCP-based remote denial-of-service issues
# Discussion Line: http://news.ycombinator.com/item?id=20205566
# Comments: 56
#
# Title: Mathematician Disproves Hedetniemi’s Graph Theory Conjecture
# Discussion Line: http://news.ycombinator.com/item?id=20203707
# Comments: 46
#
# Title: Classes vs. Data Structures
# Discussion Line: http://news.ycombinator.com/item?id=20205694
# Comments: 43
#
# Title: Malaysia Airlines Flight MH370: Where Is It?
# Discussion Line: http://news.ycombinator.com/item?id=20201557
# Comments: 40
#
# Title: VisiCalc's Spreadsheets Changed the World
# Discussion Line: http://news.ycombinator.com/item?id=20197060
# Comments: 31
#
# Title: The CIA Spied on People Through Their Smart TVs, Leaked Documents Reveal (2017)
# Discussion Line: http://news.ycombinator.com/item?id=20206536
# Comments: 25
#
# Title: Demon Core
# Discussion Line: http://news.ycombinator.com/item?id=20205876
# Comments: 22
#
# Title: The New Wilderness
# Discussion Line: http://news.ycombinator.com/item?id=20172745
# Comments: 21
#
# Title: Interview with the creators of levels.fyi
# Discussion Line: http://news.ycombinator.com/item?id=20205088
# Comments: 18
#
# Title: Building a Web-Based Motion Graphics Editor
# Discussion Line: http://news.ycombinator.com/item?id=20204258
# Comments: 18
#
# Title: Google Is Taking Charge of the RCS Rollout
# Discussion Line: http://news.ycombinator.com/item?id=20206412
# Comments: 15
#
# Title: Calculators for Contractors, Builders, Remodelers, Carpenters, Woodworkers
# Discussion Line: http://news.ycombinator.com/item?id=20189404
# Comments: 10
#
# Title: C++11 lock-free command buffers for multi-thread rendering
# Discussion Line: http://news.ycombinator.com/item?id=20203820
# Comments: 9
#
# Title: Landlords rip out escalators and walls to attract tenants like Google, Netflix
# Discussion Line: http://news.ycombinator.com/item?id=20207370
# Comments: 8
#
# Title: Presenting the Eshell
# Discussion Line: http://news.ycombinator.com/item?id=20205103
# Comments: 4
#
# Title: Mankind's Inner Ant
# Discussion Line: http://news.ycombinator.com/item?id=20207427
# Comments: 1
#
# Title: The Outsider's Guide to the Social World
# Discussion Line: http://news.ycombinator.com/item?id=20201148
# Comments: 1
#
# Title: Receiving Dead Satellites with the RTL-SDR (2014)
# Discussion Line: http://news.ycombinator.com/item?id=20185711
# Comments: 1
#
# Title: The Rascal Metaprogramming Language
# Discussion Line: http://news.ycombinator.com/item?id=20207347
# Comments: 0
#
# Title: ZeroCater (YC W11) Is Hiring a Principal Engineer in SF: Help Disrupt Lunch
# Discussion Line: http://news.ycombinator.com/item?id=20207686
# Comments: 0
#
# Title: Pachyderm 1.9 enables users to “version control” streaming data
# Discussion Line: http://news.ycombinator.com/item?id=20207369
# Comments: 0
